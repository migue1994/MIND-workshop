# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('Data.csv', sep = ',')
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %% [markdown]
# # Cálculo de estadísticas básicas

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# ## Estadisticas por agrupación de datos

# %% [markdown]
# ## Bluethoot

# %%
dfBlue=df.groupby('blue')

# %%
dfBlue.describe()
# Out:
#      battery_power                                                          \
#              count         mean         std    min    25%     50%      75%
# blue
# 0           1010.0  1233.624752  435.391348  501.0  851.0  1222.5  1596.75
# 1            990.0  1243.511111  443.653197  501.0  853.5  1232.0  1633.50
#
#              clock_speed            ... wifi      price_range            \
#          max       count      mean  ...  75%  max       count      mean
# blue                                ...
# 0     1996.0      1010.0  1.504950  ...  1.0  1.0      1010.0  1.477228
# 1     1998.0       990.0  1.539899  ...  1.0  1.0       990.0  1.523232
#
#
#            std  min  25%  50%  75%  max
# blue
# 0     1.112135  0.0  0.0  1.0  2.0  3.0
# 1     1.124669  0.0  1.0  2.0  3.0  3.0
#
# [2 rows x 160 columns]

# %% [markdown]
# ## Dual sim

# %%
dfDualSim = df.groupby('dual_sim')

# %%
dfDualSim.describe()
# Out:
#          battery_power                                                         \
#                  count         mean         std    min    25%     50%     75%
# dual_sim
# 0                981.0  1257.254842  434.814338  501.0  881.0  1253.0  1638.0
# 1               1019.0  1220.480864  443.270435  501.0  829.0  1202.0  1595.5
#
#                     blue            ... wifi      price_range            \
#              max   count      mean  ...  75%  max       count      mean
# dual_sim                            ...
# 0         1998.0   981.0  0.477064  ...  1.0  1.0       981.0  1.480122
# 1         1997.0  1019.0  0.512267  ...  1.0  1.0      1019.0  1.519136
#
#
#                std  min  25%  50%  75%  max
# dual_sim
# 0         1.113398  0.0  0.0  1.0  2.0  3.0
# 1         1.123239  0.0  1.0  2.0  3.0  3.0
#
# [2 rows x 160 columns]

# %% [markdown]
# ## Camara fontal en megapixeles

# %%
dfFrontCamera = df.groupby('fc')

# %%
dfFrontCamera.describe()
# Out:
#    battery_power                                                             \
#            count         mean         std     min      25%     50%      75%
# fc
# 0          474.0  1225.466245  427.501963   504.0   840.75  1212.0  1577.00
# 1          245.0  1185.367347  439.623558   503.0   832.00  1156.0  1595.00
# 2          189.0  1224.349206  433.312814   504.0   834.00  1231.0  1582.00
# 3          170.0  1279.788235  434.791948   503.0   904.75  1292.5  1642.75
# 4          133.0  1279.030075  444.941772   514.0   852.00  1313.0  1692.00
# 5          139.0  1250.899281  455.827155   503.0   858.50  1279.0  1642.00
# 6          112.0  1287.741071  427.223906   506.0   942.50  1275.5  1638.75
# 7          100.0  1172.600000  465.118275   502.0   763.75  1058.0  1595.25
# 8           77.0  1272.987013  467.917939   504.0   865.00  1314.0  1702.00
# 9           78.0  1192.961538  475.712683   539.0   768.75  1096.0  1700.75
# ...

# %% [markdown]
# ## Disponibilidad 4G

# %%
df4G = df.groupby('four_g')

# %%
df4G.describe()
# Out:
#        battery_power                                                         \
#                count         mean         std    min    25%     50%     75%
# four_g
# 0              957.0  1231.334378  436.977644  501.0  848.0  1216.0  1595.0
# 1             1043.0  1245.110259  441.752350  501.0  852.0  1253.0  1631.0
#
#                   blue            ... wifi      price_range            \
#            max   count      mean  ...  75%  max       count      mean
# four_g                            ...
# 0       1998.0   957.0  0.487983  ...  1.0  1.0       957.0  1.482759
# 1       1996.0  1043.0  0.501438  ...  1.0  1.0      1043.0  1.515820
#
#
#              std  min  25%  50%  75%  max
# four_g
# 0       1.106734  0.0  0.0  1.0  2.0  3.0
# 1       1.129133  0.0  1.0  2.0  3.0  3.0
#
# [2 rows x 160 columns]

# %% [markdown]
# ## Number of cores of processor

# %%
dCores = df.groupby('n_cores')
dCores.describe()
# Out:
#         battery_power                                                  \
#                 count         mean         std    min     25%     50%
# n_cores
# 1               242.0  1302.157025  438.747037  503.0  920.50  1336.0
# 2               247.0  1239.279352  427.442602  502.0  874.50  1225.0
# 3               246.0  1215.081301  442.361928  503.0  829.25  1199.5
# 4               274.0  1225.182482  437.729694  501.0  827.50  1211.0
# 5               246.0  1226.000000  419.676017  504.0  851.25  1247.5
# 6               230.0  1255.213043  441.329534  501.0  857.00  1267.0
# 7               259.0  1222.351351  443.692518  504.0  839.50  1221.0
# 8               256.0  1227.808594  462.243021  511.0  823.00  1146.0
#
#                            blue            ... wifi      price_range  \
#              75%     max  count      mean  ...  75%  max       count
# n_cores                                    ...
# 1        1689.25  1995.0  242.0  0.479339  ...  1.0  1.0       242.0
# ...

# %% [markdown]
# ## Primary Camera mega pixels

# %%
dfprimaryC = df.groupby('pc')
dfprimaryC.describe()
# Out:
#    battery_power                                                            \
#            count         mean         std    min      25%     50%      75%
# pc
# 0          101.0  1257.217822  422.503316  504.0   903.00  1261.0  1644.00
# 1          104.0  1206.173077  426.483554  518.0   816.25  1233.5  1517.25
# 2           99.0  1214.414141  463.641950  508.0   801.00  1154.0  1655.00
# 3           93.0  1257.602151  423.997748  531.0   891.00  1264.0  1676.00
# 4           95.0  1143.431579  445.832610  503.0   758.50  1063.0  1506.00
# 5           59.0  1308.389831  420.981448  570.0  1041.00  1333.0  1649.00
# 6           95.0  1276.705263  412.900969  510.0   918.00  1313.0  1568.00
# 7          119.0  1238.941176  440.926150  506.0   865.00  1197.0  1648.50
# 8           89.0  1179.314607  419.680116  502.0   790.00  1157.0  1523.00
# 9          112.0  1254.794643  453.808154  504.0   851.75  1263.5  1619.00
# ...

# %% [markdown]
# ## Has 3G or not

# %%
df3G = df.groupby('three_g')
df3G.describe()
# Out:
#         battery_power                                                         \
#                 count         mean         std    min    25%     50%     75%
# three_g
# 0               477.0  1229.473795  441.153427  501.0  841.0  1225.0  1597.0
# 1              1523.0  1241.351280  438.980277  501.0  853.5  1230.0  1619.5
#
#                    blue            ... wifi      price_range            \
#             max   count      mean  ...  75%  max       count      mean
# three_g                            ...
# 0        1995.0   477.0  0.522013  ...  1.0  1.0       477.0  1.452830
# 1        1998.0  1523.0  0.486540  ...  1.0  1.0      1523.0  1.514773
#
#
#               std  min  25%  50%  75%  max
# three_g
# 0        1.124768  0.0  0.0  1.0  2.0  3.0
# 1        1.116245  0.0  1.0  2.0  3.0  3.0
#
# [2 rows x 160 columns]

# %% [markdown]
# ## Has touch screen or not

# %%
dfTouch = df.groupby('touch_screen')

# %%
dfTouch.describe()
# Out:
#              battery_power                                                 \
#                      count         mean         std    min    25%     50%
# touch_screen
# 0                    994.0  1243.165996  439.811673  501.0  852.5  1235.0
# 1                   1006.0  1233.926441  439.199499  502.0  848.0  1224.0
#
#                                 blue           ... wifi      price_range  \
#                  75%     max   count     mean  ...  75%  max       count
# touch_screen                                   ...
# 0             1620.0  1997.0   994.0  0.48994  ...  1.0  1.0       994.0
# 1             1601.5  1998.0  1006.0  0.50000  ...  1.0  1.0      1006.0
#
#
#                   mean       std  min  25%  50%  75%  max
# touch_screen
# 0             1.534205  1.111750  0.0  1.0  2.0  3.0  3.0
# 1             1.466203  1.124291  0.0  0.0  1.0  2.0  3.0
#
# [2 rows x 160 columns]

# %% [markdown]
# ## Has wifi or not

# %%
dfWifi = df.groupby('wifi')
dfWifi.describe()
# Out:
#      battery_power                                                           \
#              count         mean         std    min     25%     50%      75%
# wifi
# 0            986.0  1242.235294  442.863905  501.0  858.50  1222.0  1630.25
# 1           1014.0  1234.904339  436.229757  501.0  844.25  1233.0  1594.50
#
#                 blue            ... touch_screen      price_range            \
#          max   count      mean  ...          75%  max       count      mean
# wifi                            ...
# 0     1998.0   986.0  0.506085  ...          1.0  1.0       986.0  1.478702
# 1     1996.0  1014.0  0.484221  ...          1.0  1.0      1014.0  1.520710
#
#
#            std  min  25%  50%  75%  max
# wifi
# 0     1.115672  0.0  0.0  1.0  2.0  3.0
# 1     1.121039  0.0  1.0  2.0  3.0  3.0
#
# [2 rows x 160 columns]

# %% [markdown]
# # Graphics

# %% [markdown]
# ## Price vs ram

# %%
sns.set(style="whitegrid")
plt.figure()
ax = sns.boxplot(x='price_range', y='ram', data=df, orient="v")

# %% [markdown]
# ## Price vs clock speed

# %%
ax = sns.boxplot(x='price_range', y='clock_speed', data=df, orient="v")

# %% [markdown]
# ## Price vs number of cores

# %%
ax = sns.boxplot(x='price_range', y='n_cores', data=df, orient="v")

# %% [markdown]
# ## Price vs batery power

# %%
ax = sns.boxplot(x='price_range', y='battery_power', data=df, orient="v")

# %% [markdown]
# ## Price vs fronted camera (Mpx)

# %%
ax = sns.boxplot(x='price_range', y='fc', data=df, orient="v")

# %% [markdown]
# ## Price vs primary camera

# %%
ax = sns.boxplot(x='price_range', y='pc', data=df, orient="v")

# %% [markdown]
# ## Price vs mobile weight

# %%
ax = sns.boxplot(x='price_range', y='mobile_wt', data=df, orient="v")

# %% [markdown]
# ## Price vs deepth of camera

# %%
ax = sns.boxplot(x='price_range', y='m_dep', data=df, orient="v")

# %% [markdown]
# ## Price vs internal memory

# %%
ax = sns.boxplot(x='price_range', y='int_memory', data=df, orient="v")

# %% [markdown]
# # Histograms

# %% [markdown]
# ## Batery power

# %%
filter_data = df.dropna(subset=['battery_power'])
plt.figure(figsize=(14,8))
sns.distplot(filter_data['battery_power'], kde=False)

# %% [markdown]
# ## Clock speed

# %%
filter_data = df.dropna(subset=['clock_speed'])
plt.figure(figsize=(14,8))
sns.distplot(filter_data['clock_speed'], kde=False)

# %% [markdown]
# ## Frontal camera

# %%
filter_data = df.dropna(subset=['fc'])
plt.figure(figsize=(14,8))
sns.distplot(filter_data['fc'], kde=False)

# %% [markdown]
# ## Internal memory

# %%
filter_data = df.dropna(subset=['int_memory'])
plt.figure(figsize=(14,8))
sns.distplot(filter_data['int_memory'], kde=False)

# %% [markdown]
# ## Mobile Depth in cm

# %%
filter_data = df.dropna(subset=['m_dep'])
plt.figure(figsize=(14,8))
sns.distplot(filter_data['m_dep'], kde=False)

# %% [markdown]
# ## mobile weight

# %%
filter_data = df.dropna(subset=['mobile_wt'])
plt.figure(figsize=(14,8))
sns.distplot(filter_data['mobile_wt'], kde=False)

# %% [markdown]
# ## Number of cores of processor

# %%
filter_data = df.dropna(subset=['n_cores'])
plt.figure(figsize=(14,8))
sns.distplot(filter_data['n_cores'], kde=False)

# %% [markdown]
# ## Primary Camera mega pixels

# %%
filter_data = df.dropna(subset=['pc'])
plt.figure(figsize=(14,8))
sns.distplot(filter_data['pc'], kde=False)

# %% [markdown]
# ## Pixel Resolution Height

# %%
filter_data = df.dropna(subset=['px_height'])
plt.figure(figsize=(14,8))
sns.distplot(filter_data['px_height'], kde=False)

# %% [markdown]
# ## Ram

# %%
filter_data = df.dropna(subset=['ram'])
plt.figure(figsize=(14,8))
sns.distplot(filter_data['ram'], kde=False)
